# %% [markdown]
# # Libraries

# %%
import os
import numpy as np
import torch
import onnx
import onnxruntime
from cardionix.models import CardioNetV2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import torch
# ----> 4 import onnx
#       5 import onnxruntime
#       6 from cardionix.models import CardioNetV2
#
# ModuleNotFoundError: No module named 'onnx'

# %% [markdown]
# # Functions

# %%
def to_numpy(tensor: torch.Tensor) -> np.ndarray:
    return tensor.detach().cpu().numpy() \
        if tensor.requires_grad \
        else tensor.cpu().numpy()

# %% [markdown]
# # Paths

# %%
DIR_PATH: str = "../weights"
_WEIGHTS_cardionetv2_multi: str = os.path.join(DIR_PATH, "multi", "cardionetv2multi.pt")
_WEIGHTS_cardionetv2uno: str = os.path.join(DIR_PATH, "uno", "cardionetv2uno.pt")

# %% [markdown]
# # Load models

# %% [markdown]
# ## Multi

# %%
multi = CardioNetV2(
    num_classes=3,
    audio_features_shape=(431, 128),
    tabular_features=50,
    rnn_layers=1,
    resnet_backbone={
        512: 2,
        1024: 2,
        2048: 2,
    },
    mixer_depth={
        "tabular": [128, 256, 512],
        "mixer": [2048]
    }
)

state_dict = torch.load(_WEIGHTS_cardionetv2_multi)
multi.load_state_dict(state_dict)
multi.eval()
# Out:
# CardioNetV2(
#   (rnn): LSTM(128, 213, batch_first=True, bidirectional=True)
#   (resnet): ResNet(
#     (stem): Sequential(
#       (0): Conv1d(431, 512, kernel_size=(7,), stride=(2,))
#       (1): MaxPool1d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (residual_groups): Sequential(
#       (0): Sequential(
#         (0): ResidualUnite(
#           (shortcut): Sequential()
#           (activation): ReLU()
#           (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#           (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ResidualUnite(
#           (shortcut): Sequential()
#           (activation): ReLU()
#           (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#           (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#       )
#       (1): Sequential(
#         (0): ResidualUnite(
#           (shortcut): Sequential(
#             (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): Conv1d(512, 1024, kernel_size=(1,), stride=(2,))
#           )
#           (activation): ReLU()
#           (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(512, 1024, kernel_size=(3,), stride=(2,), padding=(1,))
#           (bn2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ResidualUnite(
#           (shortcut): Sequential()
#           (activation): ReLU()
#           (bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=(1,))
#           (bn2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#       )
#       (2): Sequential(
#         (0): ResidualUnite(
#           (shortcut): Sequential(
#             (0): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): Conv1d(1024, 2048, kernel_size=(1,), stride=(2,))
#           )
#           (activation): ReLU()
#           (bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(1024, 2048, kernel_size=(3,), stride=(2,), padding=(1,))
#           (bn2): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(2048, 2048, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ResidualUnite(
#           (shortcut): Sequential()
#           (activation): ReLU()
#           (bn1): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(2048, 2048, kernel_size=(3,), stride=(1,), padding=(1,))
#           (bn2): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(2048, 2048, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#       )
#     )
#     (avgpool): GlobalAvgPool1d()
#   )
#   (mixer): DenseMixer(
#     (audio_fc): Sequential()
#     (tabular_fc): Sequential(
#       (0): Sequential(
#         (0): Linear(in_features=50, out_features=128, bias=True)
#         (1): ReLU()
#       )
#       (1): Sequential(
#         (0): Linear(in_features=128, out_features=256, bias=True)
#         (1): ReLU()
#       )
#       (2): Sequential(
#         (0): Linear(in_features=256, out_features=512, bias=True)
#         (1): ReLU()
#       )
#     )
#     (mixer): Sequential(
#       (0): Sequential(
#         (0): Linear(in_features=2560, out_features=2048, bias=True)
#         (1): ReLU()
#       )
#       (1): Linear(in_features=2048, out_features=3, bias=True)
#     )
#     (concat): Concat1d()
#   )
# )

# %% [markdown]
# ## Uno

# %%
uno = CardioNetV2(
    num_classes=3,
    audio_features_shape=(431, 128),
    rnn_hidden=256,
    rnn_layers=1,
    resnet_backbone={
        512: 2,
        1024: 2,
        2048: 2,
    },
    mixer_depth={
        "mixer": [1024]
    }
)

state_dict = torch.load(_WEIGHTS_cardionetv2uno)
uno.load_state_dict(state_dict)
uno.eval()
# Out:
# CardioNetV2(
#   (rnn): LSTM(128, 256, batch_first=True, bidirectional=True)
#   (resnet): ResNet(
#     (stem): Sequential(
#       (0): Conv1d(431, 512, kernel_size=(7,), stride=(2,))
#       (1): MaxPool1d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (residual_groups): Sequential(
#       (0): Sequential(
#         (0): ResidualUnite(
#           (shortcut): Sequential()
#           (activation): ReLU()
#           (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#           (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ResidualUnite(
#           (shortcut): Sequential()
#           (activation): ReLU()
#           (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#           (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#       )
#       (1): Sequential(
#         (0): ResidualUnite(
#           (shortcut): Sequential(
#             (0): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): Conv1d(512, 1024, kernel_size=(1,), stride=(2,))
#           )
#           (activation): ReLU()
#           (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(512, 1024, kernel_size=(3,), stride=(2,), padding=(1,))
#           (bn2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ResidualUnite(
#           (shortcut): Sequential()
#           (activation): ReLU()
#           (bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=(1,))
#           (bn2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#       )
#       (2): Sequential(
#         (0): ResidualUnite(
#           (shortcut): Sequential(
#             (0): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): Conv1d(1024, 2048, kernel_size=(1,), stride=(2,))
#           )
#           (activation): ReLU()
#           (bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(1024, 2048, kernel_size=(3,), stride=(2,), padding=(1,))
#           (bn2): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(2048, 2048, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ResidualUnite(
#           (shortcut): Sequential()
#           (activation): ReLU()
#           (bn1): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv1): Conv1d(2048, 2048, kernel_size=(3,), stride=(1,), padding=(1,))
#           (bn2): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv1d(2048, 2048, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#       )
#     )
#     (avgpool): GlobalAvgPool1d()
#   )
#   (mixer): DenseMixer(
#     (audio_fc): Sequential()
#     (tabular_fc): Sequential()
#     (mixer): Sequential(
#       (0): Sequential(
#         (0): Linear(in_features=2048, out_features=1024, bias=True)
#         (1): ReLU()
#       )
#       (1): Linear(in_features=1024, out_features=3, bias=True)
#     )
#     (concat): Concat1d()
#   )
# )

# %% [markdown]
# # Export to onnx

# %% [markdown]
# ## Multi-modal cardionetV2

# %%
# Input to the model
audio = torch.randn(1, 431, 128, requires_grad=True)
tabular = torch.randn(1, 50, requires_grad=True)
out = multi(audio, tabular)

# Export the model
torch.onnx.export(multi,                       # model being run
                  args=(audio, tabular),                         # model input (or a tuple for multiple inputs)
                  f="cardionetv2multi.onnx",     # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=17,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['audio', 'tabular'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                'output' : {0 : 'batch_size'}}
                  )
# Out:
# /home/merci/PycharmProjects/pet-projects/cardio-sonix-pipeline/env/lib64/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4476: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# ## Test inference

# %%
onnx_model = onnx.load("cardionetv2multi.onnx")
onnx.checker.check_model(onnx_model)
session = onnxruntime.InferenceSession("cardionetv2multi.onnx", providers=["CPUExecutionProvider"])

# %%
names = [data.name for data in session.get_inputs()]

# %%
out
# Out:
# tensor([ 3.3727, -2.5457, -1.1044], grad_fn=<AddBackward0>)

# %%
# compute ONNX Runtime output prediction
inputs = {
    "audio": to_numpy(audio),
    "tabular": to_numpy(tabular)
}

outputs = session.run(None, inputs)
outputs
# Out:
# [array([ 2.4427974 , -0.50859225, -1.9582437 ], dtype=float32)]

# %%
exp = np.exp(outputs[0])
probs = exp / np.sum(exp) 
dict(zip(classes, probs))
classes = ["audio", "tabular"]

# %%
dict(zip(classes, [audio, tabular]))
# Out:
# {'audio': tensor([[[ 1.3330, -0.2535, -0.0441,  ..., -0.3859,  0.5635,  0.0943],
#           [-0.4864, -1.8936, -0.7645,  ..., -1.3078, -0.7509,  1.8776],
#           [-1.5375, -0.4746, -1.0221,  ..., -0.2335, -0.5987, -0.8313],
#           ...,
#           [-0.3768,  0.6961, -1.3318,  ..., -1.0578,  1.1027, -0.7878],
#           [ 0.5812,  0.1098,  1.6675,  ...,  1.5028, -0.0348,  0.3104],
#           [-1.0784,  0.3393,  0.9045,  ..., -0.7405,  0.7008, -0.6168]]],
#         requires_grad=True),
#  'tabular': tensor([[-8.2140e-03, -6.4077e-01,  1.3592e+00, -1.1798e+00, -1.8600e+00,
#           -1.4538e+00, -3.1451e-03,  9.7492e-01,  3.3294e-01, -5.1764e-01,
#            4.5881e-01, -2.9778e+00,  2.8893e-01,  1.0743e+00, -1.5863e+00,
#           -1.3217e+00,  2.7726e-01, -8.7851e-01, -1.6516e+00, -8.4603e-01,
#           -1.1907e+00,  1.0038e+00,  1.6274e-03, -1.6351e-01, -1.4875e+00,
#           -4.8379e-01,  3.2532e-01, -8.1372e-01,  1.8414e+00, -8.0892e-01,
#            3.9148e-01, -4.8619e-01,  1.8152e-02, -1.3811e+00,  9.5478e-01,
#            3.6247e-01, -2.2444e+00,  1.1496e+00,  8.0339e-01, -1.0439e+00,
#            1.6020e-01, -8.6269e-01,  1.3173e+00,  4.6014e-01, -1.3285e+00,
#            2.3835e+00,  1.3734e+00,  9.6948e-01, -8.6868e-01, -5.8722e-01]],
#         requires_grad=True)}

# %%
{}.fromkeys(classes)
# Out:
# {'normal': None, 'artifact': None, 'murmur': None}

# %%
np.testing.assert_allclose(to_numpy(out), outputs[0], rtol=1e-03, atol=1e-05)

# %% [markdown]
# ## Uni-modal cardionetV2

# %%
# Input to the model
x = torch.randn(1, 431, 128, requires_grad=True)
out = uno(x)

# Export the model
torch.onnx.export(uno,                       # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  "cardionetv2uno.onnx",     # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=17,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                'output' : {0 : 'batch_size'}}
                  )
# Out:
# /home/merci/PycharmProjects/pet-projects/cardio-sonix-pipeline/env/lib64/python3.10/site-packages/torch/onnx/symbolic_opset9.py:4476: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %% [markdown]
# ## Test inference

# %%
onnx_model = onnx.load("cardionetv2uno.onnx")
onnx.checker.check_model(onnx_model)
session = onnxruntime.InferenceSession("cardionetv2uno.onnx", providers=["CPUExecutionProvider"])

# %%
x = torch.randn(1, 431, 128)
y = uno(x)
y
# Out:
# tensor([[ 2.5230, -1.4508, -1.3373]], grad_fn=<AddmmBackward0>)

# %%
# compute ONNX Runtime output prediction
inputs = {
    session.get_inputs()[0].name: to_numpy(x)
}

outputs = session.run(None, inputs)
outputs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # compute ONNX Runtime output prediction
#       2 inputs = {
# ----> 3     session.get_inputs()[0].name: to_numpy(x)
#       4 }
#       6 outputs = session.run("output", inputs)
#       7 outputs
#
# NameError: name 'x' is not defined

# %%
np.testing.assert_allclose(to_numpy(y), outputs[0], rtol=1e-03, atol=1e-05)
